# %% [markdown]
# Manually classify clips

# %%
import cv2
import os
import shutil

# %%
input_folder = "datasets\\open_setup\\unclassified"
output_base = "datasets\\open_setup\\videos"

classes = ["cone_jet", "dripping", "intermitent", "multi_jet", "no_flow", "undefined"]

for cls in classes:
    os.makedirs(os.path.join(output_base, cls), exist_ok=True)

videos = [f for f in os.listdir(input_folder) if f.endswith(".mp4")]
videos.sort()

print("Controls:")
print("1–6 → assign class")
print("q   → quit")
print("n   → skip video")

for video_name in videos:

    video_path = os.path.join(input_folder, video_name)
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Error opening:", video_name)
        continue

    print(f"\nLabeling: {video_name}")

    while True:
        ret, frame = cap.read()
        if not ret:
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            continue

        cv2.imshow("Video", frame)

        key = cv2.waitKey(int(1000 / cap.get(cv2.CAP_PROP_FPS))) & 0xFF

        if key == ord('q'):
            cap.release()
            cv2.destroyAllWindows()
            exit()

        elif key == ord('n'):
            print("Skipped")
            break

        elif key in [ord('1'), ord('2'), ord('3'), ord('4'), ord('5'), ord('6')]:
            class_index = int(chr(key)) - 1
            destination = os.path.join(output_base, classes[class_index], video_name)

            cap.release()
            cv2.destroyAllWindows()

            shutil.move(video_path, destination)
            print(f"Moved to {classes[class_index]}")
            break

    cap.release()
    cv2.destroyAllWindows()

print("Done labeling.")
# Out:
# Controls:
# 1–6 → assign class
# q   → quit
# n   → skip video
#
# Labeling: clip_001_000.mp4
# Moved to no_flow
#
# Labeling: clip_001_001.mp4
# Moved to no_flow
#
# Labeling: clip_001_002.mp4
# Moved to no_flow
#
# Labeling: clip_001_003.mp4
# Moved to no_flow
#
# Labeling: clip_001_004.mp4
# Moved to no_flow
#
# Labeling: clip_001_005.mp4
# Moved to no_flow
#
# Labeling: clip_001_006.mp4
# Moved to no_flow
#
# Labeling: clip_001_007.mp4
# Moved to no_flow
#
# Labeling: clip_001_008.mp4
# Moved to no_flow
#
# Labeling: clip_001_009.mp4
# Moved to no_flow
#
# Labeling: clip_001_010.mp4
# Moved to no_flow
#
# Labeling: clip_001_011.mp4
# Moved to no_flow
#
# Labeling: clip_001_012.mp4
# Moved to no_flow
#
# Labeling: clip_001_013.mp4
# Moved to no_flow
#
# Labeling: clip_001_014.mp4
# Moved to no_flow
#
# Labeling: clip_001_015.mp4
# Moved to no_flow
#
# Labeling: clip_001_016.mp4
# Moved to no_flow
#
# Labeling: clip_001_017.mp4
# Moved to no_flow
#
# Labeling: clip_001_018.mp4
# Moved to no_flow
#
# Labeling: clip_001_019.mp4
# Moved to no_flow
#
# Labeling: clip_001_020.mp4
# Moved to no_flow
#
# Labeling: clip_001_021.mp4
# Moved to no_flow
#
# Labeling: clip_001_022.mp4
# Moved to no_flow
#
# Labeling: clip_001_023.mp4
# Moved to no_flow
#
# Labeling: clip_001_024.mp4
# Moved to no_flow
#
# Labeling: clip_001_025.mp4
# Moved to no_flow
#
# Labeling: clip_001_026.mp4
# Moved to no_flow
#
# Labeling: clip_001_027.mp4
# Moved to no_flow
#
# Labeling: clip_001_028.mp4
# Moved to no_flow
#
# Labeling: clip_001_029.mp4
# Moved to no_flow
#
# Labeling: clip_001_030.mp4
# Moved to no_flow
#
# Labeling: clip_001_031.mp4
# Moved to no_flow
#
# Labeling: clip_001_032.mp4
# Moved to no_flow
#
# Labeling: clip_001_033.mp4
# Moved to no_flow
#
# Labeling: clip_001_034.mp4
# Moved to no_flow
#
# Labeling: clip_001_035.mp4
# Moved to no_flow
#
# Labeling: clip_001_036.mp4
# Moved to no_flow
#
# Labeling: clip_001_037.mp4
# Moved to no_flow
#
# Labeling: clip_001_038.mp4
# Moved to no_flow
#
# Labeling: clip_001_039.mp4
# Moved to no_flow
#
# Labeling: clip_001_040.mp4
# Moved to no_flow
#
# Labeling: clip_001_041.mp4
# Moved to multi_jet
#
# Labeling: clip_001_042.mp4
# Moved to multi_jet
#
# Labeling: clip_001_043.mp4
# Moved to multi_jet
#
# Labeling: clip_001_044.mp4
# Moved to dripping
#
# Labeling: clip_001_045.mp4
# Moved to dripping
#
# Labeling: clip_001_046.mp4
# Moved to dripping
#
# Labeling: clip_001_047.mp4
# Moved to dripping
#
# Labeling: clip_001_048.mp4
# Moved to dripping
#
# Labeling: clip_001_049.mp4
# Moved to dripping
#
# Labeling: clip_001_050.mp4
# Moved to dripping
#
# Labeling: clip_001_051.mp4
# Moved to dripping
#
# Labeling: clip_001_052.mp4
# Moved to dripping
#
# Labeling: clip_001_053.mp4
# Moved to dripping
#
# Labeling: clip_001_054.mp4
# Moved to intermitent
#
# Labeling: clip_001_055.mp4
# Moved to intermitent
#
# Labeling: clip_001_056.mp4
# Moved to intermitent
#
# Labeling: clip_001_057.mp4
# Moved to intermitent
#
# Labeling: clip_001_058.mp4
# Moved to undefined
#
# Labeling: clip_001_059.mp4
# Moved to cone_jet
#
# Labeling: clip_001_060.mp4
# Moved to cone_jet
#
# Labeling: clip_001_061.mp4
# Moved to cone_jet
#
# Labeling: clip_001_062.mp4
# Moved to cone_jet
#
# Labeling: clip_001_063.mp4
# Moved to undefined
#
# Labeling: clip_001_064.mp4
# Moved to undefined
#
# Labeling: clip_001_065.mp4
# Moved to undefined
#
# Labeling: clip_001_066.mp4
# Moved to multi_jet
#
# Labeling: clip_001_067.mp4
# Moved to dripping
#
# Labeling: clip_001_068.mp4
# Moved to dripping
#
# Labeling: clip_001_069.mp4
# Moved to dripping
#
# Labeling: clip_001_070.mp4
# Moved to dripping
#
# Labeling: clip_001_071.mp4
# Moved to dripping
#
# Labeling: clip_001_072.mp4
# Moved to dripping
#
# Labeling: clip_001_073.mp4
# Moved to dripping
#
# Labeling: clip_001_074.mp4
# Moved to dripping
#
# Labeling: clip_001_075.mp4
# Moved to dripping
#
# Labeling: clip_001_076.mp4
# Moved to dripping
#
# Labeling: clip_001_077.mp4
# Moved to intermitent
#
# Labeling: clip_001_078.mp4
# Moved to intermitent
#
# Labeling: clip_001_079.mp4
# Moved to intermitent
#
# Labeling: clip_001_080.mp4
# Moved to intermitent
#
# Labeling: clip_001_081.mp4
# Moved to cone_jet
#
# Labeling: clip_001_082.mp4
# Moved to intermitent
#
# Labeling: clip_001_083.mp4
# Moved to intermitent
#
# Labeling: clip_001_084.mp4
# Moved to cone_jet
#
# Labeling: clip_001_085.mp4
# Moved to intermitent
#
# Labeling: clip_001_086.mp4
# Moved to intermitent
#
# Labeling: clip_001_087.mp4
# Moved to undefined
#
# Labeling: clip_001_088.mp4
# Moved to undefined
#
# Labeling: clip_001_089.mp4
# Moved to undefined
#
# Labeling: clip_001_090.mp4
# Moved to dripping
#
# Labeling: clip_001_091.mp4
# Moved to dripping
#
# Labeling: clip_001_092.mp4
# Moved to dripping
#
# Labeling: clip_001_093.mp4
# Moved to dripping
#
# Labeling: clip_001_094.mp4
# Moved to dripping
#
# Labeling: clip_001_095.mp4
# Moved to dripping
#
# Labeling: clip_001_096.mp4
# Moved to dripping
#
# Labeling: clip_001_097.mp4
# Moved to dripping
#
# Labeling: clip_001_098.mp4
# Moved to dripping
#
# Labeling: clip_001_099.mp4
# Moved to intermitent
#
# Labeling: clip_001_100.mp4
# Moved to intermitent
#
# Labeling: clip_001_101.mp4
# Moved to intermitent
#
# Labeling: clip_001_102.mp4
# Moved to intermitent
#
# Labeling: clip_001_103.mp4
# Moved to intermitent
#
# Labeling: clip_001_104.mp4
# Moved to cone_jet
#
# Labeling: clip_001_105.mp4
# Moved to intermitent
#
# Labeling: clip_001_106.mp4
# Moved to intermitent
#
# Labeling: clip_001_107.mp4
# Moved to intermitent
#
# Labeling: clip_001_108.mp4
# Moved to intermitent
#
# Labeling: clip_001_109.mp4
# Moved to intermitent
#
# Labeling: clip_001_110.mp4
# Moved to undefined
#
# Labeling: clip_001_111.mp4
# Moved to undefined
#
# Labeling: clip_001_112.mp4
# Moved to undefined
#
# Labeling: clip_001_113.mp4
# Moved to dripping
#
# Labeling: clip_001_114.mp4
# Moved to dripping
#
# Labeling: clip_001_115.mp4
# Moved to dripping
#
# Labeling: clip_001_116.mp4
# Moved to dripping
#
# Labeling: clip_001_117.mp4
# Moved to dripping
#
# Labeling: clip_001_118.mp4
# Moved to dripping
#
# Labeling: clip_001_119.mp4
# Moved to dripping
#
# Labeling: clip_001_120.mp4
# Moved to dripping
#
# Labeling: clip_001_121.mp4
# Moved to dripping
#
# Labeling: clip_001_122.mp4
# Moved to intermitent
#
# Labeling: clip_001_123.mp4
# Moved to intermitent
#
# Labeling: clip_001_124.mp4
# Moved to intermitent
#
# Labeling: clip_001_125.mp4
# Moved to intermitent
#
# Labeling: clip_001_126.mp4
# Moved to intermitent
#
# Labeling: clip_001_127.mp4
# Moved to intermitent
#
# Labeling: clip_001_128.mp4
# Moved to intermitent
#
# Labeling: clip_001_129.mp4
# Moved to intermitent
#
# Labeling: clip_001_130.mp4
# Moved to intermitent
#
# Labeling: clip_001_131.mp4
# Moved to undefined
#
# Labeling: clip_001_132.mp4
# Moved to undefined
#
# Labeling: clip_001_133.mp4
# Moved to undefined
#
# Labeling: clip_001_134.mp4
# Moved to multi_jet
#
# Labeling: clip_001_135.mp4
# Moved to multi_jet
#
# Labeling: clip_001_136.mp4
# Moved to dripping
#
# Labeling: clip_001_137.mp4
# Moved to dripping
#
# Labeling: clip_001_138.mp4
# Moved to dripping
#
# Labeling: clip_001_139.mp4
# Moved to dripping
#
# Labeling: clip_001_140.mp4
# Moved to dripping
#
# Labeling: clip_001_141.mp4
# Moved to dripping
#
# Labeling: clip_001_142.mp4
# Moved to no_flow
#
# Labeling: clip_001_143.mp4
# Moved to no_flow
#
# Labeling: clip_001_144.mp4
# Moved to no_flow
#
# Labeling: clip_001_145.mp4
# Moved to no_flow
#
# Labeling: clip_001_146.mp4
# Moved to no_flow
#
# Labeling: clip_001_147.mp4
# Moved to no_flow
#
# Labeling: clip_001_148.mp4
# Moved to no_flow
#
# Labeling: clip_001_149.mp4
# Moved to no_flow
#
# Labeling: clip_001_150.mp4
# Moved to no_flow
#
# Labeling: clip_001_151.mp4
# Moved to no_flow
#
# Labeling: clip_001_152.mp4
# Moved to no_flow
#
# Labeling: clip_001_153.mp4
# Moved to no_flow
#
# Labeling: clip_001_154.mp4
# Moved to no_flow
#
# Labeling: clip_001_155.mp4
# Moved to no_flow
#
# Labeling: clip_001_156.mp4
# Moved to no_flow
#
# Labeling: clip_001_157.mp4
# Moved to no_flow
#
# Labeling: clip_001_158.mp4
# Moved to no_flow
#
# Labeling: clip_001_159.mp4
# Moved to no_flow
#
# Labeling: clip_001_160.mp4
# Moved to no_flow
#
# Labeling: clip_001_161.mp4
# Moved to no_flow
#
# Labeling: clip_001_162.mp4
# Moved to no_flow
#
# Labeling: clip_001_163.mp4
# Moved to no_flow
#
# Labeling: clip_001_164.mp4
# Moved to no_flow
#
# Labeling: clip_001_165.mp4
# Moved to no_flow
#
# Labeling: clip_001_166.mp4
# Moved to no_flow
#
# Labeling: clip_001_167.mp4
# Moved to no_flow
#
# Labeling: clip_001_168.mp4
# Moved to no_flow
#
# Labeling: clip_001_169.mp4
# Moved to no_flow
#
# Labeling: clip_001_170.mp4
# Moved to no_flow
#
# Labeling: clip_001_171.mp4
# Moved to no_flow
#
# Labeling: clip_001_172.mp4
# Moved to no_flow
#
# Labeling: clip_001_173.mp4
# Moved to no_flow
#
# Labeling: clip_001_174.mp4
# Moved to no_flow
#
# Labeling: clip_001_175.mp4
# Moved to no_flow
#
# Labeling: clip_001_176.mp4
# Moved to no_flow
#
# Labeling: clip_001_177.mp4
# Moved to no_flow
#
# Labeling: clip_001_178.mp4
# Moved to multi_jet
#
# Labeling: clip_001_179.mp4
# Moved to multi_jet
#
# Labeling: clip_001_180.mp4
# Moved to multi_jet
#
# Labeling: clip_001_181.mp4
# Moved to multi_jet
#
# Labeling: clip_002_000.mp4
# Moved to dripping
#
# Labeling: clip_002_001.mp4
# Moved to dripping
#
# Labeling: clip_002_002.mp4
# Moved to intermitent
#
# Labeling: clip_002_003.mp4
# Moved to intermitent
#
# Labeling: clip_002_004.mp4
# Moved to intermitent
#
# Labeling: clip_002_005.mp4
# Moved to intermitent
#
# Labeling: clip_002_006.mp4
# Moved to intermitent
#
# Labeling: clip_002_007.mp4
# Moved to undefined
#
# Labeling: clip_002_008.mp4
# Moved to undefined
#
# Labeling: clip_002_009.mp4
# Moved to intermitent
#
# Labeling: clip_002_010.mp4
# Moved to undefined
#
# Labeling: clip_002_011.mp4
# Moved to undefined
#
# Labeling: clip_002_012.mp4
# Moved to undefined
#
# Labeling: clip_002_013.mp4
# Moved to undefined
#
# Labeling: clip_002_014.mp4
# Moved to undefined
#
# Labeling: clip_002_015.mp4
# Moved to undefined
#
# Labeling: clip_002_016.mp4
# Moved to undefined
#
# Labeling: clip_002_017.mp4
# Moved to undefined
#
# Labeling: clip_002_018.mp4
# Moved to multi_jet
#
# Labeling: clip_002_019.mp4
# Moved to dripping
#
# Labeling: clip_002_020.mp4
# Moved to dripping
#
# Labeling: clip_002_021.mp4
# Moved to dripping
#
# Labeling: clip_002_022.mp4
# Moved to intermitent
#
# Labeling: clip_003_000.mp4
# Moved to no_flow
#
# Labeling: clip_003_001.mp4
# Moved to no_flow
#
# Labeling: clip_003_002.mp4
# Moved to no_flow
#
# Labeling: clip_003_003.mp4
# Moved to dripping
#
# Labeling: clip_003_004.mp4
# Moved to intermitent
#
# Labeling: clip_003_005.mp4
# Moved to intermitent
#
# Labeling: clip_003_006.mp4
# Moved to intermitent
#
# Labeling: clip_003_007.mp4
# Moved to cone_jet
#
# Labeling: clip_003_008.mp4
# Moved to cone_jet
#
# Labeling: clip_003_009.mp4
# Moved to cone_jet
#
# Labeling: clip_003_010.mp4
# Moved to undefined
#
# Labeling: clip_003_011.mp4
# Moved to undefined
#
# Labeling: clip_003_012.mp4
# Moved to multi_jet
#
# Labeling: clip_003_013.mp4
# Moved to multi_jet
#
# Labeling: clip_003_014.mp4
# Moved to multi_jet
#
# Labeling: clip_003_015.mp4
# Moved to multi_jet
#
# Labeling: clip_003_016.mp4
# Moved to no_flow
#
# Labeling: clip_003_017.mp4
# Moved to no_flow
#
# Labeling: clip_003_018.mp4
# Moved to multi_jet
#
# Labeling: clip_003_019.mp4
# Moved to dripping
#
# Labeling: clip_003_020.mp4
# Moved to dripping
#
# Labeling: clip_003_021.mp4
# Moved to dripping
#
# Labeling: clip_003_022.mp4
# Moved to dripping
#
# Labeling: clip_003_023.mp4
# Moved to dripping
#
# Labeling: clip_003_024.mp4
# Moved to intermitent
#
# Labeling: clip_003_025.mp4
# Moved to intermitent
#
# Labeling: clip_003_026.mp4
# Moved to cone_jet
#
# Labeling: clip_003_027.mp4
# Moved to cone_jet
#
# Labeling: clip_003_028.mp4
# Moved to intermitent
#
# Labeling: clip_003_029.mp4
# Moved to undefined
#
# Labeling: clip_003_030.mp4
# Moved to undefined
#
# Labeling: clip_003_031.mp4
# Moved to undefined
#
# Labeling: clip_003_032.mp4
# Moved to multi_jet
#
# Labeling: clip_003_033.mp4
# Moved to multi_jet
#
# Labeling: clip_003_034.mp4
# Moved to multi_jet
#
# Labeling: clip_003_035.mp4
# Moved to multi_jet
#
# Labeling: clip_003_036.mp4
# Moved to multi_jet
#
# Labeling: clip_003_037.mp4
# Moved to multi_jet
#
# Labeling: clip_003_038.mp4
# Moved to multi_jet
#
# Labeling: clip_003_039.mp4
# Moved to dripping
#
# Labeling: clip_003_040.mp4
# Moved to dripping
#
# Labeling: clip_003_041.mp4
# Moved to dripping
#
# Labeling: clip_003_042.mp4
# Moved to dripping
#
# Labeling: clip_003_043.mp4
# Moved to intermitent
#
# Labeling: clip_003_044.mp4
# Moved to intermitent
#
# Labeling: clip_003_045.mp4
# Moved to intermitent
#
# Labeling: clip_003_046.mp4
# Moved to intermitent
#
# Labeling: clip_003_047.mp4
# Moved to intermitent
#
# Labeling: clip_003_048.mp4
# Moved to intermitent
#
# Labeling: clip_003_049.mp4
# Moved to intermitent
#
# Labeling: clip_003_050.mp4
# Moved to undefined
#
# Labeling: clip_003_051.mp4
# Moved to undefined
#
# Labeling: clip_003_052.mp4
# Moved to multi_jet
#
# Labeling: clip_003_053.mp4
# Moved to multi_jet
#
# Labeling: clip_003_054.mp4
# Moved to multi_jet
#
# Labeling: clip_003_055.mp4
# Moved to multi_jet
#
# Labeling: clip_003_056.mp4
# Moved to multi_jet
#
# Labeling: clip_003_057.mp4
# Moved to multi_jet
#
# Labeling: clip_003_058.mp4
# Moved to multi_jet
#
# Labeling: clip_003_059.mp4
# Moved to dripping
#
# Labeling: clip_003_060.mp4
# Moved to dripping
#
# Labeling: clip_003_061.mp4
# Moved to dripping
#
# Labeling: clip_003_062.mp4
# Moved to dripping
#
# Labeling: clip_003_063.mp4
# Moved to intermitent
#
# Labeling: clip_003_064.mp4
# Moved to intermitent
#
# Labeling: clip_003_065.mp4
# Moved to intermitent
#
# Labeling: clip_003_066.mp4
# Moved to intermitent
#
# Labeling: clip_003_067.mp4
# Moved to intermitent
#
# Labeling: clip_003_068.mp4
# Moved to intermitent
#
# Labeling: clip_003_069.mp4
# Moved to intermitent
#
# Labeling: clip_003_070.mp4
# Moved to undefined
#
# Labeling: clip_003_071.mp4
# Moved to undefined
#
# Labeling: clip_003_072.mp4
# Moved to undefined
#
# Labeling: clip_003_073.mp4
# Moved to multi_jet
#
# Labeling: clip_003_074.mp4
# Moved to multi_jet
#
# Labeling: clip_003_075.mp4
# Moved to multi_jet
#
# Labeling: clip_003_076.mp4
# Moved to multi_jet
#
# Labeling: clip_003_077.mp4
# Moved to multi_jet
#
# Labeling: clip_003_078.mp4
# Moved to multi_jet
#
# Labeling: clip_003_079.mp4
# Moved to dripping
#
# Labeling: clip_003_080.mp4
# Moved to dripping
#
# Labeling: clip_003_081.mp4
# Moved to dripping
#
# Labeling: clip_003_082.mp4
# Moved to intermitent
#
# Labeling: clip_003_083.mp4
# Moved to intermitent
#
# Labeling: clip_003_084.mp4
# Moved to intermitent
#
# Labeling: clip_003_085.mp4
# Moved to intermitent
#
# Labeling: clip_003_086.mp4
# Moved to intermitent
#
# Labeling: clip_003_087.mp4
# Moved to undefined
#
# Labeling: clip_003_088.mp4
# Moved to intermitent
#
# Labeling: clip_003_089.mp4
# Moved to cone_jet
#
# Labeling: clip_003_090.mp4
# Moved to undefined
#
# Labeling: clip_003_091.mp4
# Moved to undefined
#
# Labeling: clip_003_092.mp4
# Moved to undefined
#
# Labeling: clip_003_093.mp4
# Moved to undefined
#
# Labeling: clip_003_094.mp4
# Moved to multi_jet
#
# Labeling: clip_003_095.mp4
# Moved to multi_jet
#
# Labeling: clip_003_096.mp4
# Moved to multi_jet
#
# Labeling: clip_003_097.mp4
# Moved to multi_jet
#
# Labeling: clip_003_098.mp4
# Moved to multi_jet
#
# Labeling: clip_003_099.mp4
# Moved to dripping
#
# Labeling: clip_003_100.mp4
# Moved to dripping
#
# Labeling: clip_003_101.mp4
# Moved to dripping
#
# Labeling: clip_003_102.mp4
# Moved to dripping
#
# Labeling: clip_003_103.mp4
# Moved to intermitent
#
# Labeling: clip_003_104.mp4
# Moved to intermitent
#
# Labeling: clip_003_105.mp4
# Moved to intermitent
#
# Labeling: clip_003_106.mp4
# Moved to intermitent
#
# Labeling: clip_003_107.mp4
# Moved to undefined
#
# Labeling: clip_003_108.mp4
# Moved to undefined
#
# Labeling: clip_003_109.mp4
# Moved to undefined
#
# Labeling: clip_003_110.mp4
# Moved to undefined
#
# Labeling: clip_003_111.mp4
# Moved to undefined
#
# Labeling: clip_003_112.mp4
# Moved to undefined
#
# Labeling: clip_003_113.mp4
# Moved to undefined
#
# Labeling: clip_003_114.mp4
# Moved to undefined
#
# Labeling: clip_003_115.mp4
# Moved to multi_jet
#
# Labeling: clip_003_116.mp4
# Moved to multi_jet
#
# Labeling: clip_003_117.mp4
# Moved to multi_jet
#
# Labeling: clip_003_118.mp4
# Moved to multi_jet
#
# Labeling: clip_003_119.mp4
# Moved to dripping
#
# Labeling: clip_003_120.mp4
# Moved to dripping
#
# Labeling: clip_003_121.mp4
# Moved to dripping
#
# Labeling: clip_003_122.mp4
# Moved to dripping
#
# Labeling: clip_003_123.mp4
# Moved to intermitent
#
# Labeling: clip_003_124.mp4
# Moved to intermitent
#
# Labeling: clip_003_125.mp4
# Moved to intermitent
#
# Labeling: clip_003_126.mp4
# Moved to intermitent
#
# Labeling: clip_003_127.mp4
# Moved to undefined
#
# Labeling: clip_003_128.mp4
# Moved to undefined
#
# Labeling: clip_003_129.mp4
# Moved to undefined
#
# Labeling: clip_003_130.mp4
# Moved to undefined
#
# Labeling: clip_003_131.mp4
# Moved to undefined
#
# Labeling: clip_003_132.mp4
# Moved to undefined
#
# Labeling: clip_003_133.mp4
# Moved to undefined
#
# Labeling: clip_003_134.mp4
# Moved to undefined
#
# Labeling: clip_003_135.mp4
# Moved to undefined
#
# Labeling: clip_003_136.mp4
# Moved to multi_jet
#
# Labeling: clip_003_137.mp4
# Moved to multi_jet
#
# Labeling: clip_003_138.mp4
# Moved to multi_jet
#
# Labeling: clip_003_139.mp4
# Moved to dripping
#
# Labeling: clip_003_140.mp4
# Moved to dripping
#
# Labeling: clip_003_141.mp4
# Moved to dripping
#
# Labeling: clip_003_142.mp4
# Moved to dripping
#
# Labeling: clip_003_143.mp4
# Moved to intermitent
#
# Labeling: clip_003_144.mp4
# Moved to intermitent
#
# Labeling: clip_003_145.mp4
# Moved to intermitent
#
# Labeling: clip_003_146.mp4
# Moved to intermitent
#
# Labeling: clip_003_147.mp4
# Moved to undefined
#
# Labeling: clip_003_148.mp4
# Moved to undefined
#
# Labeling: clip_003_149.mp4
# Moved to undefined
#
# Labeling: clip_003_150.mp4
# Moved to undefined
#
# Labeling: clip_003_151.mp4
# Moved to undefined
#
# Labeling: clip_003_152.mp4
# Moved to undefined
#
# Labeling: clip_003_153.mp4
# Moved to undefined
#
# Labeling: clip_003_154.mp4
# Moved to undefined
#
# Labeling: clip_003_155.mp4
# Moved to undefined
#
# Labeling: clip_003_156.mp4
# Moved to undefined
#
# Labeling: clip_003_157.mp4
# Moved to multi_jet
#
# Labeling: clip_003_158.mp4
# Moved to multi_jet
#
# Labeling: clip_004_000.mp4
# Moved to no_flow
#
# Labeling: clip_004_001.mp4
# Moved to no_flow
#
# Labeling: clip_004_002.mp4
# Moved to no_flow
#
# Labeling: clip_004_003.mp4
# Moved to no_flow
#
# Labeling: clip_004_004.mp4
# Moved to no_flow
#
# Labeling: clip_004_005.mp4
# Moved to no_flow
#
# Labeling: clip_004_006.mp4
# Moved to no_flow
#
# Labeling: clip_004_007.mp4
# Moved to no_flow
#
# Labeling: clip_004_008.mp4
# Moved to no_flow
#
# Labeling: clip_004_009.mp4
# Moved to no_flow
#
# Labeling: clip_004_010.mp4
# Moved to no_flow
#
# Labeling: clip_004_011.mp4
# Moved to no_flow
#
# Labeling: clip_004_012.mp4
# Moved to no_flow
#
# Labeling: clip_004_013.mp4
# Moved to no_flow
#
# Labeling: clip_004_014.mp4
# Moved to no_flow
#
# Labeling: clip_004_015.mp4
# Moved to no_flow
#
# Labeling: clip_004_016.mp4
# Moved to no_flow
#
# Labeling: clip_004_017.mp4
# Moved to no_flow
#
# Labeling: clip_004_018.mp4
# Moved to no_flow
#
# Labeling: clip_004_019.mp4
# Moved to no_flow
#
# Labeling: clip_004_020.mp4
# Moved to no_flow
#
# Labeling: clip_004_021.mp4
# Moved to no_flow
#
# Labeling: clip_004_022.mp4
# Moved to no_flow
#
# Labeling: clip_004_023.mp4
# Moved to no_flow
#
# Labeling: clip_004_024.mp4
# Moved to no_flow
#
# Labeling: clip_004_025.mp4
# Moved to no_flow
#
# Labeling: clip_004_026.mp4
# Moved to no_flow
#
# Labeling: clip_004_027.mp4
# Moved to no_flow
#
# Labeling: clip_004_028.mp4
# Moved to intermitent
#
# Labeling: clip_004_029.mp4
# Moved to undefined
#
# Labeling: clip_004_030.mp4
# Moved to undefined
#
# Labeling: clip_004_031.mp4
# Moved to no_flow
#
# Labeling: clip_004_032.mp4
# Moved to no_flow
#
# Labeling: clip_004_033.mp4
# Moved to no_flow
#
# Labeling: clip_004_034.mp4
# Moved to no_flow
#
# Labeling: clip_004_035.mp4
# Moved to no_flow
#
# Labeling: clip_004_036.mp4
# Moved to no_flow
#
# Labeling: clip_004_037.mp4
# Moved to no_flow
#
# Labeling: clip_004_038.mp4
# Moved to no_flow
#
# Labeling: clip_004_039.mp4
# Moved to no_flow
#
# Labeling: clip_004_040.mp4
# Moved to no_flow
#
# Labeling: clip_004_041.mp4
# Moved to no_flow
#
# Labeling: clip_004_042.mp4
# Moved to no_flow
#
# Labeling: clip_004_043.mp4
# Moved to dripping
#
# Labeling: clip_004_044.mp4
# Moved to dripping
#
# Labeling: clip_004_045.mp4
# Moved to intermitent
#
# Labeling: clip_004_046.mp4
# Moved to intermitent
#
# Labeling: clip_004_047.mp4
# Moved to cone_jet
#
# Labeling: clip_004_048.mp4
# Moved to cone_jet
#
# Labeling: clip_004_049.mp4
# Moved to intermitent
#
# Labeling: clip_004_050.mp4
# Moved to undefined
#
# Labeling: clip_004_051.mp4
# Moved to no_flow
#
# Labeling: clip_004_052.mp4
# Moved to no_flow
#
# Labeling: clip_004_053.mp4
# Moved to no_flow
#
# Labeling: clip_004_054.mp4
# Moved to no_flow
#
# Labeling: clip_004_055.mp4
# Moved to no_flow
#
# Labeling: clip_004_056.mp4
# Moved to no_flow
#
# Labeling: clip_004_057.mp4
# Moved to no_flow
#
# Labeling: clip_004_058.mp4
# Moved to no_flow
#
# Labeling: clip_004_059.mp4
# Moved to no_flow
#
# Labeling: clip_004_060.mp4
# Moved to no_flow
#
# Labeling: clip_004_061.mp4
# Moved to dripping
#
# Labeling: clip_004_062.mp4
# Moved to dripping
#
# Labeling: clip_004_063.mp4
# Moved to dripping
#
# Labeling: clip_004_064.mp4
# Moved to dripping
#
# Labeling: clip_004_065.mp4
# Moved to intermitent
#
# Labeling: clip_004_066.mp4
# Moved to cone_jet
#
# Labeling: clip_004_067.mp4
# Moved to intermitent
#
# Labeling: clip_004_068.mp4
# Moved to cone_jet
#
# Labeling: clip_004_069.mp4
# Moved to cone_jet
#
# Labeling: clip_004_070.mp4
# Moved to cone_jet
#
# Labeling: clip_004_071.mp4
# Moved to no_flow
#
# Labeling: clip_004_072.mp4
# Moved to no_flow
#
# Labeling: clip_004_073.mp4
# Moved to no_flow
#
# Labeling: clip_004_074.mp4
# Moved to no_flow
#
# Labeling: clip_004_075.mp4
# Moved to no_flow
#
# Labeling: clip_004_076.mp4
# Moved to no_flow
#
# Labeling: clip_004_077.mp4
# Moved to no_flow
#
# Labeling: clip_004_078.mp4
# Moved to no_flow
#
# Labeling: clip_004_079.mp4
# Moved to dripping
#
# Labeling: clip_004_080.mp4
# Moved to dripping
#
# Labeling: clip_004_081.mp4
# Moved to dripping
#
# Labeling: clip_004_082.mp4
# Moved to dripping
#
# Labeling: clip_004_083.mp4
# Moved to dripping
#
# Labeling: clip_004_084.mp4
# Moved to intermitent
#
# Labeling: clip_004_085.mp4
# Moved to intermitent
#
# Labeling: clip_004_086.mp4
# Moved to cone_jet
#
# Labeling: clip_004_087.mp4
# Moved to cone_jet
#
# Labeling: clip_004_088.mp4
# Moved to cone_jet
#
# Labeling: clip_004_089.mp4
# Moved to cone_jet
#
# Labeling: clip_004_090.mp4
# Moved to cone_jet
#
# Labeling: clip_004_091.mp4
# Moved to multi_jet
#
# Labeling: clip_004_092.mp4
# Moved to multi_jet
#
# Labeling: clip_004_093.mp4
# Moved to multi_jet
#
# Labeling: clip_004_094.mp4
# Moved to multi_jet
#
# Labeling: clip_004_095.mp4
# Moved to multi_jet
#
# Labeling: clip_004_096.mp4
# Moved to multi_jet
#
# Labeling: clip_004_097.mp4
# Moved to multi_jet
#
# Labeling: clip_004_098.mp4
# Moved to multi_jet
#
# Labeling: clip_004_099.mp4
# Moved to dripping
#
# Labeling: clip_004_100.mp4
# Moved to dripping
#
# Labeling: clip_004_101.mp4
# Moved to dripping
#
# Labeling: clip_004_102.mp4
# Moved to dripping
#
# Labeling: clip_004_103.mp4
# Moved to dripping
#
# Labeling: clip_004_104.mp4
# Moved to intermitent
#
# Labeling: clip_004_105.mp4
# Moved to intermitent
#
# Labeling: clip_004_106.mp4
# Moved to intermitent
#
# Labeling: clip_004_107.mp4
# Moved to intermitent
#
# Labeling: clip_004_108.mp4
# Moved to cone_jet
#
# Labeling: clip_004_109.mp4
# Moved to cone_jet
#
# Labeling: clip_004_110.mp4
# Moved to cone_jet
#
# Labeling: clip_004_111.mp4
# Moved to multi_jet
#
# Labeling: clip_004_112.mp4
# Moved to multi_jet
#
# Labeling: clip_004_113.mp4
# Moved to multi_jet
#
# Labeling: clip_004_114.mp4
# Moved to multi_jet
#
# Labeling: clip_004_115.mp4
# Moved to multi_jet
#
# Labeling: clip_004_116.mp4
# Moved to multi_jet
#
# Labeling: clip_004_117.mp4
# Moved to multi_jet
#
# Labeling: clip_004_118.mp4
# Moved to multi_jet
#
# Labeling: clip_004_119.mp4
# Moved to dripping
#
# Labeling: clip_004_120.mp4
# Moved to dripping
#
# Labeling: clip_004_121.mp4
# Moved to dripping
#
# Labeling: clip_004_122.mp4
# Moved to dripping
#
# Labeling: clip_004_123.mp4
# Moved to dripping
#
# Labeling: clip_004_124.mp4
# Moved to dripping
#
# Labeling: clip_004_125.mp4
# Moved to intermitent
#
# Labeling: clip_004_126.mp4
# Moved to intermitent
#
# Labeling: clip_004_127.mp4
# Moved to intermitent
#
# Labeling: clip_004_128.mp4
# Moved to intermitent
#
# Labeling: clip_004_129.mp4
# Moved to undefined
#
# Labeling: clip_004_130.mp4
# Moved to undefined
#
# Labeling: clip_004_131.mp4
# Moved to undefined
#
# Labeling: clip_004_132.mp4
# Moved to multi_jet
#
# Labeling: clip_004_133.mp4
# Moved to multi_jet
#
# Labeling: clip_004_134.mp4
# Moved to multi_jet
#
# Labeling: clip_004_135.mp4
# Moved to multi_jet
#
# Labeling: clip_004_136.mp4
# Moved to multi_jet
#
# Labeling: clip_004_137.mp4
# Moved to multi_jet
#
# Labeling: clip_004_138.mp4
# Moved to no_flow
#
# Labeling: clip_004_139.mp4
# Moved to dripping
#
# Labeling: clip_004_140.mp4
# Moved to dripping
#
# Labeling: clip_004_141.mp4
# Moved to dripping
#
# Labeling: clip_004_142.mp4
# Moved to dripping
#
# Labeling: clip_004_143.mp4
# Moved to dripping
#
# Labeling: clip_004_144.mp4
# Moved to intermitent
#
# Labeling: clip_004_145.mp4
# Moved to intermitent
#
# Labeling: clip_004_146.mp4
# Moved to intermitent
#
# Labeling: clip_004_147.mp4
# Moved to intermitent
#
# Labeling: clip_004_148.mp4
# Moved to cone_jet
#
# Labeling: clip_004_149.mp4
# Moved to cone_jet
#
# Labeling: clip_004_150.mp4
# Moved to cone_jet
#
# Labeling: clip_004_151.mp4
# Moved to multi_jet
#
# Labeling: clip_004_152.mp4
# Moved to multi_jet
#
# Labeling: clip_004_153.mp4
# Moved to multi_jet
#
# Labeling: clip_004_154.mp4
# Moved to multi_jet
#
# Labeling: clip_004_155.mp4
# Moved to multi_jet
#
# Labeling: clip_004_156.mp4
# Moved to multi_jet
#
# Labeling: clip_004_157.mp4
# Moved to multi_jet
#
# Labeling: clip_004_158.mp4
# Moved to multi_jet
#
# Labeling: clip_005_000.mp4
# Moved to dripping
#
# Labeling: clip_005_001.mp4
# Moved to dripping
#
# Labeling: clip_005_002.mp4
# Moved to dripping
#
# Labeling: clip_005_003.mp4
# Moved to dripping
#
# Labeling: clip_005_004.mp4
# Moved to intermitent
#
# Labeling: clip_005_005.mp4
# Moved to intermitent
#
# Labeling: clip_005_006.mp4
# Moved to intermitent
#
# Labeling: clip_005_007.mp4
# Moved to undefined
#
# Labeling: clip_005_008.mp4
# Moved to undefined
#
# Labeling: clip_005_009.mp4
# Moved to undefined
#
# Labeling: clip_005_010.mp4
# Moved to undefined
#
# Labeling: clip_005_011.mp4
# Moved to undefined
#
# Labeling: clip_005_012.mp4
# Moved to undefined
#
# Labeling: clip_005_013.mp4
# Moved to undefined
#
# Labeling: clip_005_014.mp4
# Moved to undefined
#
# Labeling: clip_005_015.mp4
# Moved to undefined
#
# Labeling: clip_005_016.mp4
# Moved to undefined
#
# Labeling: clip_005_017.mp4
# Moved to multi_jet
#
# Labeling: clip_005_018.mp4
# Moved to multi_jet
#
# Labeling: clip_005_019.mp4
# Moved to multi_jet
#
# Labeling: clip_005_020.mp4
# Moved to multi_jet
#
# Labeling: clip_005_021.mp4
# Moved to dripping
#
# Labeling: clip_005_022.mp4
# Moved to dripping
#
# Labeling: clip_005_023.mp4
# Moved to dripping
#
# Labeling: clip_005_024.mp4
# Moved to dripping
#
# Labeling: clip_005_025.mp4
# Moved to dripping
#
# Labeling: clip_005_026.mp4
# Moved to intermitent
#
# Labeling: clip_005_027.mp4
# Moved to intermitent
#
# Labeling: clip_005_028.mp4
# Moved to intermitent
#
# Labeling: clip_005_029.mp4
# Moved to intermitent
#
# Labeling: clip_005_030.mp4
# Moved to undefined
#
# Labeling: clip_005_031.mp4
# Moved to undefined
#
# Labeling: clip_005_032.mp4
# Moved to undefined
#
# Labeling: clip_005_033.mp4
# Moved to undefined
#
# Labeling: clip_005_034.mp4
# Moved to undefined
#
# Labeling: clip_005_035.mp4
# Moved to undefined
#
# Labeling: clip_005_036.mp4
# Moved to undefined
#
# Labeling: clip_005_037.mp4
# Moved to undefined
#
# Labeling: clip_005_038.mp4
# Moved to undefined
#
# Labeling: clip_005_039.mp4
# Moved to multi_jet
#
# Labeling: clip_005_040.mp4
# Moved to multi_jet
#
# Labeling: clip_005_041.mp4
# Moved to multi_jet
#
# Labeling: clip_005_042.mp4
# Moved to dripping
#
# Labeling: clip_005_043.mp4
# Moved to dripping
#
# Labeling: clip_005_044.mp4
# Moved to dripping
#
# Labeling: clip_005_045.mp4
# Moved to dripping
#
# Labeling: clip_005_046.mp4
# Moved to dripping
#
# Labeling: clip_005_047.mp4
# Moved to intermitent
#
# Labeling: clip_005_048.mp4
# Moved to intermitent
#
# Labeling: clip_005_049.mp4
# Moved to intermitent
#
# Labeling: clip_005_050.mp4
# Moved to intermitent
#
# Labeling: clip_005_051.mp4
# Moved to intermitent
#
# Labeling: clip_005_052.mp4
# Moved to undefined
#
# Labeling: clip_005_053.mp4
# Moved to undefined
#
# Labeling: clip_005_054.mp4
# Moved to undefined
#
# Labeling: clip_005_055.mp4
# Moved to undefined
#
# Labeling: clip_005_056.mp4
# Moved to undefined
#
# Labeling: clip_005_057.mp4
# Moved to undefined
#
# Labeling: clip_005_058.mp4
# Moved to undefined
#
# Labeling: clip_005_059.mp4
# Moved to undefined
#
# Labeling: clip_005_060.mp4
# Moved to undefined
#
# Labeling: clip_005_061.mp4
# Moved to undefined
#
# Labeling: clip_005_062.mp4
# Moved to undefined
#
# Labeling: clip_005_063.mp4
# Moved to dripping
#
# Labeling: clip_005_064.mp4
# Moved to dripping
#
# Labeling: clip_005_065.mp4
# Moved to dripping
#
# Labeling: clip_005_066.mp4
# Moved to dripping
#
# Labeling: clip_005_067.mp4
# Moved to intermitent
#
# Labeling: clip_005_068.mp4
# Moved to intermitent
#
# Labeling: clip_005_069.mp4
# Moved to intermitent
#
# Labeling: clip_005_070.mp4
# Moved to intermitent
#
# Labeling: clip_005_071.mp4
# Moved to intermitent
#
# Labeling: clip_005_072.mp4
# Moved to intermitent
#
# Labeling: clip_005_073.mp4
# Moved to undefined
#
# Labeling: clip_005_074.mp4
# Moved to undefined
#
# Labeling: clip_005_075.mp4
# Moved to undefined
#
# Labeling: clip_005_076.mp4
# Moved to undefined
#
# Labeling: clip_005_077.mp4
# Moved to undefined
#
# Labeling: clip_005_078.mp4
# Moved to undefined
#
# Labeling: clip_005_079.mp4
# Moved to undefined
#
# Labeling: clip_005_080.mp4
# Moved to undefined
#
# Labeling: clip_005_081.mp4
# Moved to undefined
#
# Labeling: clip_005_082.mp4
# Moved to undefined
#
# Labeling: clip_005_083.mp4
# Moved to undefined
#
# Labeling: clip_005_084.mp4
# Moved to dripping
#
# Labeling: clip_005_085.mp4
# Moved to dripping
#
# Labeling: clip_005_086.mp4
# Moved to dripping
#
# Labeling: clip_005_087.mp4
# Moved to intermitent
#
# Labeling: clip_005_088.mp4
# Moved to intermitent
#
# Labeling: clip_005_089.mp4
# Moved to intermitent
#
# Labeling: clip_005_090.mp4
# Moved to intermitent
#
# Labeling: clip_005_091.mp4
# Moved to intermitent
#
# Labeling: clip_005_092.mp4
# Moved to undefined
#
# Labeling: clip_005_093.mp4
# Moved to undefined
#
# Labeling: clip_005_094.mp4
# Moved to undefined
#
# Labeling: clip_005_095.mp4
# Moved to undefined
#
# Labeling: clip_005_096.mp4
# Moved to undefined
#
# Labeling: clip_005_097.mp4
# Moved to undefined
#
# Labeling: clip_005_098.mp4
# Moved to undefined
#
# Labeling: clip_005_099.mp4
# Moved to undefined
#
# Labeling: clip_005_100.mp4
# Moved to undefined
#
# Labeling: clip_005_101.mp4
# Moved to undefined
#
# Labeling: clip_005_102.mp4
# Moved to undefined
#
# Labeling: clip_005_103.mp4
# Moved to undefined
#
# Labeling: clip_005_104.mp4
# Moved to dripping
#
# Labeling: clip_005_105.mp4
# Moved to dripping
#
# Labeling: clip_005_106.mp4
# Moved to dripping
#
# Labeling: clip_005_107.mp4
# Moved to dripping
#
# Labeling: clip_005_108.mp4
# Moved to intermitent
#
# Labeling: clip_005_109.mp4
# Moved to intermitent
#
# Labeling: clip_005_110.mp4
# Moved to intermitent
#
# Labeling: clip_005_111.mp4
# Moved to intermitent
#
# Labeling: clip_005_112.mp4
# Moved to undefined
#
# Labeling: clip_005_113.mp4
# Moved to undefined
#
# Labeling: clip_005_114.mp4
# Moved to undefined
#
# Labeling: clip_005_115.mp4
# Moved to undefined
#
# Labeling: clip_005_116.mp4
# Moved to undefined
#
# Labeling: clip_005_117.mp4
# Moved to undefined
#
# Labeling: clip_005_118.mp4
# Moved to undefined
#
# Labeling: clip_005_119.mp4
# Moved to undefined
#
# Labeling: clip_005_120.mp4
# Moved to undefined
#
# Labeling: clip_005_121.mp4
# Moved to undefined
#
# Labeling: clip_005_122.mp4
# Moved to undefined
#
# Labeling: clip_005_123.mp4
# Moved to undefined
#
# Labeling: clip_005_124.mp4
# Moved to undefined
#
# Labeling: clip_005_125.mp4
# Moved to dripping
#
# Labeling: clip_005_126.mp4
# Moved to dripping
#
# Labeling: clip_005_127.mp4
# Moved to dripping
#
# Labeling: clip_005_128.mp4
# Moved to dripping
#
# Labeling: clip_005_129.mp4
# Moved to dripping
#
# Labeling: clip_005_130.mp4
# Moved to dripping
#
# Labeling: clip_005_131.mp4
# Moved to intermitent
#
# Labeling: clip_005_132.mp4
# Moved to intermitent
#
# Labeling: clip_005_133.mp4
# Moved to intermitent
#
# Labeling: clip_005_134.mp4
# Moved to intermitent
#
# Labeling: clip_005_135.mp4
# Moved to undefined
#
# Labeling: clip_005_136.mp4
# Moved to intermitent
#
# Labeling: clip_005_137.mp4
# Moved to undefined
#
# Labeling: clip_005_138.mp4
# Moved to undefined
#
# Labeling: clip_005_139.mp4
# Moved to undefined
#
# Labeling: clip_005_140.mp4
# Moved to undefined
#
# Labeling: clip_005_141.mp4
# Moved to undefined
#
# Labeling: clip_005_142.mp4
# Moved to undefined
#
# Labeling: clip_005_143.mp4
# Moved to undefined
#
# Labeling: clip_005_144.mp4
# Moved to undefined
#
# Labeling: clip_005_145.mp4
# Moved to undefined
#
# Labeling: clip_005_146.mp4
# Moved to undefined
#
# Labeling: clip_005_147.mp4
# Moved to undefined
#
# Labeling: clip_005_148.mp4
# Moved to dripping
#
# Labeling: clip_005_149.mp4
# Moved to dripping
#
# Labeling: clip_005_150.mp4
# Moved to dripping
#
# Labeling: clip_005_151.mp4
# Moved to dripping
#
# Labeling: clip_005_152.mp4
# Moved to dripping
#
# Labeling: clip_005_153.mp4
# Moved to intermitent
#
# Labeling: clip_005_154.mp4
# Moved to intermitent
#
# Labeling: clip_005_155.mp4
# Moved to intermitent
#
# Labeling: clip_005_156.mp4
# Moved to intermitent
#
# Labeling: clip_005_157.mp4
# Moved to intermitent
#
# Labeling: clip_005_158.mp4
# Moved to undefined
#
# Labeling: clip_006_000.mp4
# Moved to dripping
#
# Labeling: clip_006_001.mp4
# Moved to dripping
#
# Labeling: clip_006_002.mp4
# Moved to dripping
#
# Labeling: clip_006_003.mp4
# Moved to intermitent
#
# Labeling: clip_006_004.mp4
# Moved to intermitent
#
# Labeling: clip_006_005.mp4
# Moved to intermitent
#
# Labeling: clip_006_006.mp4
# Moved to intermitent
#
# Labeling: clip_006_007.mp4
# Moved to undefined
#
# Labeling: clip_006_008.mp4
# Moved to undefined
#
# Labeling: clip_006_009.mp4
# Moved to undefined
#
# Labeling: clip_006_010.mp4
# Moved to undefined
#
# Labeling: clip_006_011.mp4
# Moved to undefined
#
# Labeling: clip_006_012.mp4
# Moved to undefined
#
# Labeling: clip_006_013.mp4
# Moved to undefined
#
# Labeling: clip_006_014.mp4
# Moved to undefined
#
# Labeling: clip_006_015.mp4
# Moved to undefined
#
# Labeling: clip_006_016.mp4
# Moved to undefined
#
# Labeling: clip_006_017.mp4
# Moved to undefined
#
# Labeling: clip_006_018.mp4
# Moved to undefined
#
# Labeling: clip_006_019.mp4
# Moved to undefined
#
# Labeling: clip_006_020.mp4
# Moved to dripping
#
# Labeling: clip_006_021.mp4
# Moved to dripping
#
# Labeling: clip_006_022.mp4
# Moved to dripping
#
# Labeling: clip_006_023.mp4
# Moved to dripping
#
# Labeling: clip_006_024.mp4
# Moved to intermitent
#
# Labeling: clip_006_025.mp4
# Moved to intermitent
#
# Labeling: clip_006_026.mp4
# Moved to intermitent
#
# Labeling: clip_006_027.mp4
# Moved to intermitent
#
# Labeling: clip_006_028.mp4
# Moved to undefined
#
# Labeling: clip_006_029.mp4
# Moved to undefined
#
# Labeling: clip_006_030.mp4
# Moved to undefined
#
# Labeling: clip_006_031.mp4
# Moved to undefined
#
# Labeling: clip_006_032.mp4
# Moved to undefined
#
# Labeling: clip_006_033.mp4
# Moved to undefined
#
# Labeling: clip_006_034.mp4
# Moved to undefined
#
# Labeling: clip_006_035.mp4
# Moved to undefined
#
# Labeling: clip_006_036.mp4
# Moved to undefined
#
# Labeling: clip_006_037.mp4
# Moved to undefined
#
# Labeling: clip_006_038.mp4
# Moved to undefined
#
# Labeling: clip_006_039.mp4
# Moved to undefined
#
# Labeling: clip_006_040.mp4
# Moved to undefined
#
# Labeling: clip_006_041.mp4
# Moved to dripping
#
# Labeling: clip_006_042.mp4
# Moved to dripping
#
# Labeling: clip_006_043.mp4
# Moved to dripping
#
# Labeling: clip_006_044.mp4
# Moved to dripping
#
# Labeling: clip_006_045.mp4
# Moved to intermitent
#
# Labeling: clip_006_046.mp4
# Moved to intermitent
#
# Labeling: clip_006_047.mp4
# Moved to intermitent
#
# Labeling: clip_006_048.mp4
# Moved to intermitent
#
# Labeling: clip_006_049.mp4
# Moved to undefined
#
# Labeling: clip_006_050.mp4
# Moved to undefined
#
# Labeling: clip_006_051.mp4
# Moved to undefined
#
# Labeling: clip_006_052.mp4
# Moved to undefined
#
# Labeling: clip_006_053.mp4
# Moved to undefined
#
# Labeling: clip_006_054.mp4
# Moved to undefined
#
# Labeling: clip_006_055.mp4
# Moved to undefined
#
# Labeling: clip_006_056.mp4
# Moved to undefined
#
# Labeling: clip_006_057.mp4
# Moved to undefined
#
# Labeling: clip_006_058.mp4
# Moved to undefined
#
# Labeling: clip_006_059.mp4
# Moved to undefined
#
# Labeling: clip_006_060.mp4
# Moved to undefined
#
# Labeling: clip_006_061.mp4
# Moved to dripping
#
# Labeling: clip_006_062.mp4
# Moved to dripping
#
# Labeling: clip_006_063.mp4
# Moved to dripping
#
# Labeling: clip_006_064.mp4
# Moved to dripping
#
# Labeling: clip_006_065.mp4
# Moved to intermitent
#
# Labeling: clip_006_066.mp4
# Moved to intermitent
#
# Labeling: clip_006_067.mp4
# Moved to intermitent
#
# Labeling: clip_006_068.mp4
# Moved to intermitent
#
# Labeling: clip_006_069.mp4
# Moved to undefined
#
# Labeling: clip_006_070.mp4
# Moved to undefined
#
# Labeling: clip_006_071.mp4
# Moved to undefined
#
# Labeling: clip_006_072.mp4
# Moved to undefined
#
# Labeling: clip_006_073.mp4
# Moved to undefined
#
# Labeling: clip_006_074.mp4
# Moved to undefined
#
# Labeling: clip_006_075.mp4
# Moved to undefined
#
# Labeling: clip_006_076.mp4
# Moved to undefined
#
# Labeling: clip_006_077.mp4
# Moved to undefined
#
# Labeling: clip_006_078.mp4
# Moved to undefined
#
# Labeling: clip_006_079.mp4
# Moved to undefined
#
# Labeling: clip_006_080.mp4
# Moved to undefined
#
# Labeling: clip_006_081.mp4
# Moved to dripping
#
# Labeling: clip_006_082.mp4
# Moved to dripping
#
# Labeling: clip_006_083.mp4
# Moved to dripping
#
# Labeling: clip_006_084.mp4
# Moved to dripping
#
# Labeling: clip_006_085.mp4
# Moved to intermitent
#
# Labeling: clip_006_086.mp4
# Moved to intermitent
#
# Labeling: clip_006_087.mp4
# Moved to intermitent
#
# Labeling: clip_006_088.mp4
# Moved to intermitent
#
# Labeling: clip_006_089.mp4
# Moved to undefined
#
# Labeling: clip_006_090.mp4
# Moved to undefined
#
# Labeling: clip_006_091.mp4
# Moved to undefined
#
# Labeling: clip_006_092.mp4
# Moved to undefined
#
# Labeling: clip_006_093.mp4
# Moved to undefined
#
# Labeling: clip_006_094.mp4
# Moved to undefined
#
# Labeling: clip_006_095.mp4
# Moved to undefined
#
# Labeling: clip_006_096.mp4
# Moved to undefined
#
# Labeling: clip_006_097.mp4
# Moved to undefined
#
# Labeling: clip_006_098.mp4
# Moved to undefined
#
# Labeling: clip_006_099.mp4
# Moved to undefined
#
# Labeling: clip_006_100.mp4
# Moved to undefined
#
# Labeling: clip_006_101.mp4
# Moved to dripping
#
# Labeling: clip_006_102.mp4
# Moved to dripping
#
# Labeling: clip_006_103.mp4
# Moved to dripping
#
# Labeling: clip_006_104.mp4
# Moved to dripping
#
# Labeling: clip_006_105.mp4
# Moved to intermitent
#
# Labeling: clip_006_106.mp4
# Moved to intermitent
#
# Labeling: clip_006_107.mp4
# Moved to intermitent
#
# Labeling: clip_006_108.mp4
# Moved to intermitent
#
# Labeling: clip_006_109.mp4
# Moved to intermitent
#
# Labeling: clip_006_110.mp4
# Moved to undefined
#
# Labeling: clip_006_111.mp4
# Moved to undefined
#
# Labeling: clip_006_112.mp4
# Moved to undefined
#
# Labeling: clip_006_113.mp4
# Moved to undefined
#
# Labeling: clip_006_114.mp4
# Moved to undefined
#
# Labeling: clip_006_115.mp4
# Moved to undefined
#
# Labeling: clip_006_116.mp4
# Moved to undefined
#
# Labeling: clip_006_117.mp4
# Moved to undefined
#
# Labeling: clip_006_118.mp4
# Moved to undefined
#
# Labeling: clip_006_119.mp4
# Moved to undefined
#
# Labeling: clip_006_120.mp4
# Moved to undefined
#
# Labeling: clip_006_121.mp4
# Moved to undefined
#
# Labeling: clip_006_122.mp4
# Moved to dripping
#
# Labeling: clip_006_123.mp4
# Moved to dripping
#
# Labeling: clip_006_124.mp4
# Moved to dripping
#
# Labeling: clip_006_125.mp4
# Moved to intermitent
#
# Labeling: clip_006_126.mp4
# Moved to intermitent
#
# Labeling: clip_006_127.mp4
# Moved to intermitent
#
# Labeling: clip_006_128.mp4
# Moved to intermitent
#
# Labeling: clip_006_129.mp4
# Moved to intermitent
#
# Labeling: clip_006_130.mp4
# Moved to undefined
#
# Labeling: clip_006_131.mp4
# Moved to undefined
#
# Labeling: clip_006_132.mp4
# Moved to undefined
#
# Labeling: clip_006_133.mp4
# Moved to undefined
#
# Labeling: clip_006_134.mp4
# Moved to undefined
#
# Labeling: clip_006_135.mp4
# Moved to undefined
#
# Labeling: clip_006_136.mp4
# Moved to undefined
#
# Labeling: clip_006_137.mp4
# Moved to undefined
#
# Labeling: clip_006_138.mp4
# Moved to undefined
#
# Labeling: clip_006_139.mp4
# Moved to undefined
#
# Labeling: clip_006_140.mp4
# Moved to undefined
#
# Labeling: clip_006_141.mp4
# Moved to undefined
#
# Labeling: clip_006_142.mp4
# Moved to undefined
#
# Labeling: clip_006_143.mp4
# Moved to dripping
#
# Labeling: clip_006_144.mp4
# Moved to dripping
#
# Labeling: clip_006_145.mp4
# Moved to dripping
#
# Labeling: clip_006_146.mp4
# Moved to dripping
#
# Labeling: clip_006_147.mp4
# Moved to dripping
#
# Labeling: clip_006_148.mp4
# Moved to intermitent
#
# Labeling: clip_006_149.mp4
# Moved to intermitent
#
# Labeling: clip_006_150.mp4
# Moved to intermitent
#
# Labeling: clip_006_151.mp4
# Moved to intermitent
#
# Labeling: clip_006_152.mp4
# Moved to undefined
#
# Labeling: clip_006_153.mp4
# Moved to undefined
#
# Labeling: clip_006_154.mp4
# Moved to undefined
#
# Labeling: clip_006_155.mp4
# Moved to undefined
#
# Labeling: clip_006_156.mp4
# Moved to undefined
#
# Labeling: clip_006_157.mp4
# Moved to undefined
#
# Labeling: clip_006_158.mp4
# Moved to undefined
# Done labeling.
